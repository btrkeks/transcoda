# %% [markdown]
# # Polish Manual Fixes
#
# Browse and edit `4_manual_fixes` transcriptions with side-by-side real scans and Verovio previews.

# %%
from pathlib import Path

from polish_manual_fixes import PolishManualFixApp

project_root = Path.cwd().parent
normalized_dir = project_root / 'data' / 'interim' / 'val' / 'polish-scores' / '3_normalized'
manual_dir = project_root / 'data' / 'interim' / 'val' / 'polish-scores' / '4_manual_fixes'

# %%
# Optional: set hf_cache_dir='/tmp/hf_datasets_cache' if your default HF cache has permission issues.
# Tune heights here if you want more room for previews or editor.
app = PolishManualFixApp(
    normalized_dir=str(normalized_dir),
    manual_dir=str(manual_dir),
    hf_cache_dir=None,
    render_timeout_s=15.0,
    preview_panel_max_height_px=760,
    editor_height_px=300,
)
app.show()
